# %% [markdown]
# [超详细Pyecharts 1.x教程](https://www.cnblogs.com/awesometang/p/12330742.html)

# %%
import pandas as pd
import re
import platform
from pathlib import Path
from pyecharts.charts import Line,Bar, Pie, Kline
from pyecharts import options as opts
from pyecharts.render import make_snapshot
from snapshot_phantomjs import snapshot
from pyecharts.globals import ThemeType

# %%
if (platform.system() == 'Windows'):
    Vol_Price_Dir = Path('D:/Stock_Data/Vol_Price')  # 分价数据存储目录
else:
    Vol_Price_Dir = Path.home() / 'Stock_Data/Vol_Price'

vpfile = Vol_Price_Dir/'vp.h5'  #分价数据文件
df = pd.read_hdf(vpfile)
for code in set(df['ts_code']):
    vp=df.loc[df.ts_code==code]
    days = set(vp.trade_date)
    datalist = []
    for tdate in days:
        tt = vp[vp.trade_date == tdate]
        tmp = tt.sort_values(by='成交').tail()
        datalist.append(tmp)
    vdata = pd.concat(datalist, ignore_index=True)
    print(code,'最近几日成交情况:')
    print(vdata)
    print('汇总:')
    print(vdata.groupby('价格').sum().sort_values(by='成交'))
    print('-------------------------------------------------------')
# Out:
# 600057 最近几日成交情况:
#       价格     成交   比例  竞买率 ts_code  name trade_date
# 0   5.92  17943   6%  52%  600057  厦门象屿   20200605
# 1   5.85  18017   6%  42%  600057  厦门象屿   20200605
# 2   5.99  18855   6%  26%  600057  厦门象屿   20200605
# 3   5.88  18991   6%  30%  600057  厦门象屿   20200605
# 4   6.00  19079   6%  42%  600057  厦门象屿   20200605
# 5   5.95  15056   8%  32%  600057  厦门象屿   20200608
# 6   5.94  15656   9%  58%  600057  厦门象屿   20200608
# 7   5.96  18899  10%  42%  600057  厦门象屿   20200608
# 8   5.98  20103  11%  63%  600057  厦门象屿   20200608
# 9   5.97  23665  13%  56%  600057  厦门象屿   20200608
# 10  5.66  17858   8%  31%  600057  厦门象屿   20200611
# 11  5.73  18220   8%  41%  600057  厦门象屿   20200611
# 12  5.65  20219   9%  52%  600057  厦门象屿   20200611
# 13  5.74  25852  12%  57%  600057  厦门象屿   20200611
# 14  5.72  29497  13%  32%  600057  厦门象屿   20200611
# 15  5.92  14195   9%  56%  600057  厦门象屿   20200609
# 16  5.88  16566  11%  19%  600057  厦门象屿   20200609
# 17  5.91  22028  15%  51%  600057  厦门象屿   20200609
# 18  5.89  28121  19%  23%  600057  厦门象屿   20200609
# 19  5.90  30671  20%  47%  600057  厦门象屿   20200609
# 20  5.67  17529   7%  38%  600057  厦门象屿   20200612
# 21  5.57  25051  10%  26%  600057  厦门象屿   20200612
# 22  5.65  28465  11%  36%  600057  厦门象屿   20200612
# 23  5.59  31376  12%  52%  600057  厦门象屿   20200612
# 24  5.58  31442  12%  68%  600057  厦门象屿   20200612
# 25  5.81  25577   9%  79%  600057  厦门象屿   20200610
# 26  5.79  27328   9%  22%  600057  厦门象屿   20200610
# 27  5.77  27381   9%  51%  600057  厦门象屿   20200610
# 28  5.75  27927  10%  89%  600057  厦门象屿   20200610
# 29  5.80  45677  16%  71%  600057  厦门象屿   20200610
# 汇总:
#          成交
# 价格
# 5.95  15056
# 5.94  15656
# 5.67  17529
# 5.66  17858
# 5.85  18017
# 23  4.23  26966  26%  29%  600105  永鼎股份   20200612
# 24  4.24  32204  31%  46%  600105  永鼎股份   20200612
# 25  4.09  16976   6%  36%  600105  永鼎股份   20200610
# 26  4.12  18524   7%  44%  600105  永鼎股份   20200610
# 27  4.33  20012   7%  37%  600105  永鼎股份   20200610
# 28  4.11  20903   8%  58%  600105  永鼎股份   20200610
# 29  4.10  26259  10%  63%  600105  永鼎股份   20200610
# 汇总:
#          成交
# 价格
# 4.08   6246
# 4.20   6791
# 4.22   7595
# 4.04   8930
# 4.07  10758
# 4.06  14005
# 4.16  16690
# 4.09  16976
# 4.05  17518
# 4.25  18325
# 4.10  26259
# 4.23  26966
# 4.31  26989
# 4.35  30763
# 4.32  31702
# 4.15  32160
# 4.24  32204
# 4.34  35423
# 4.11  38429
# 4.33  52583
# 4.14  64543
# 4.13  65509
# 4.12  68286
# -------------------------------------------------------

# %%
test=vdata.groupby('价格').sum().sort_values(by='成交')
test.reset_index(inplace=True)

# %%
test.价格.astype('U')
# Out:
# 0     4.08
# 1      4.2
# 2     4.22
# 3     4.04
# 4     4.07
# 5     4.06
# 6     4.16
# 7     4.09
# 8     4.05
# 9     4.25
# 10     4.1
# 11    4.23
# 12    4.31
# 13    4.35
# 14    4.32
# 15    4.15
# 16    4.24
# 17    4.34
# 18    4.11
# 19    4.33
# 20    4.14
# 21    4.13
# 22    4.12
# Name: 价格, dtype: object

# %%
m1=test['价格'].astype('U')
m2=test['成交']
type(m1[0])
# Out:
# str

# %%
bar = (Bar()
       .add_yaxis('成交手数',m2.tolist())
       .add_xaxis(m1.tolist())
       .set_global_opts(title_opts=opts.TitleOpts(title="分价统计", subtitle="代码"))
      )
# 进行渲染
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="55f81b28f7ab44dea9ff150e07127f93" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_55f81b28f7ab44dea9ff150e07127f93 = echarts.init(
#                     document.getElementById('55f81b28f7ab44dea9ff150e07127f93'), 'white', {renderer: 'canvas'});
#                 var option_55f81b28f7ab44dea9ff150e07127f93 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6210\u4ea4\u624b\u6570",
#             "data": [
#                 6246,
#                 6791,
#                 7595,
#                 8930,
#                 10758,
#                 14005,
#                 16690,
#                 16976,
#                 17518,
#                 18325,
#                 26259,
#                 26966,
#                 26989,
#                 30763,
#                 31702,
#                 32160,
#                 32204,
#                 35423,
#                 38429,
#                 52583,
#                 64543,
#                 65509,
#                 68286
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6210\u4ea4\u624b\u6570"
#             ],
#             "selected": {
#                 "\u6210\u4ea4\u624b\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "4.08",
#                 "4.2",
#                 "4.22",
#                 "4.04",
#                 "4.07",
#                 "4.06",
#                 "4.16",
#                 "4.09",
#                 "4.05",
#                 "4.25",
#                 "4.1",
#                 "4.23",
#                 "4.31",
#                 "4.35",
#                 "4.32",
#                 "4.15",
#                 "4.24",
#                 "4.34",
#                 "4.11",
#                 "4.33",
#                 "4.14",
#                 "4.13",
#                 "4.12"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5206\u4ef7\u7edf\u8ba1",
#             "subtext": "\u4ee3\u7801"
#         }
#     ]
# };
#                 chart_55f81b28f7ab44dea9ff150e07127f93.setOption(option_55f81b28f7ab44dea9ff150e07127f93);
#         });
#     </script>

# %%
# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]

# 1.x版本支持链式调用
bar = (Bar()
       .add_xaxis(cate[:4])
       .add_yaxis('电商渠道', data1[:4])
       .add_yaxis('门店', data2[:4])
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="这是副标题"))
      )
# 进行渲染
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b12947b5eaf45bca16bde179018c1da" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b12947b5eaf45bca16bde179018c1da = echarts.init(
#                     document.getElementById('2b12947b5eaf45bca16bde179018c1da'), 'white', {renderer: 'canvas'});
#                 var option_2b12947b5eaf45bca16bde179018c1da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u8fd9\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2b12947b5eaf45bca16bde179018c1da.setOption(option_2b12947b5eaf45bca16bde179018c1da);
#         });
#     </script>

# %%
# 单独调用
bar = Bar()
bar.add_xaxis(cate)
bar.add_yaxis('电商渠道', data1)
bar.add_yaxis('门店', data2)
bar.set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9ff3e4315b574297ba2f89c15acc03c7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9ff3e4315b574297ba2f89c15acc03c7 = echarts.init(
#                     document.getElementById('9ff3e4315b574297ba2f89c15acc03c7'), 'white', {renderer: 'canvas'});
#                 var option_9ff3e4315b574297ba2f89c15acc03c7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9ff3e4315b574297ba2f89c15acc03c7.setOption(option_9ff3e4315b574297ba2f89c15acc03c7);
#         });
#     </script>

# %%
"""
全局配置项使用示例：
1. 标题 & 副标题
2. 关闭图例
3. 显示工具箱
"""
bar = (Bar()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1)
       .add_yaxis('门店', data2)
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"),
                        toolbox_opts=opts.ToolboxOpts(),
                        legend_opts=opts.LegendOpts(is_show=False))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b464037989664af19bf8e50887f1cde4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b464037989664af19bf8e50887f1cde4 = echarts.init(
#                     document.getElementById('b464037989664af19bf8e50887f1cde4'), 'white', {renderer: 'canvas'});
#                 var option_b464037989664af19bf8e50887f1cde4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {}
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             },
#             "brush": {
#                 "icon": {},
#                 "title": {
#                     "rect": "\u77e9\u5f62\u9009\u62e9",
#                     "polygon": "\u5708\u9009",
#                     "lineX": "\u6a2a\u5411\u9009\u62e9",
#                     "lineY": "\u7eb5\u5411\u9009\u62e9",
#                     "keep": "\u4fdd\u6301\u9009\u62e9",
#                     "clear": "\u6e05\u9664\u9009\u62e9"
#                 }
#             }
#         }
#     }
# };
#                 chart_b464037989664af19bf8e50887f1cde4.setOption(option_b464037989664af19bf8e50887f1cde4);
#         });
#     </script>

# %%
"""
全局配置项使用示例：
1. 标题 & 副标题
2. 显示图例,并指定图标样式
3. 显示视觉映射配置项
"""
bar = (Bar()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1)
       .add_yaxis('门店', data2)
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"),
                        visualmap_opts=opts.VisualMapOpts(is_show=True),
                        legend_opts=opts.LegendOpts(is_show=True,legend_icon='circle'))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="59ae621faf0e4fcaa9347bbbb279866c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_59ae621faf0e4fcaa9347bbbb279866c = echarts.init(
#                     document.getElementById('59ae621faf0e4fcaa9347bbbb279866c'), 'white', {renderer: 'canvas'});
#                 var option_59ae621faf0e4fcaa9347bbbb279866c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "icon": "circle"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_59ae621faf0e4fcaa9347bbbb279866c.setOption(option_59ae621faf0e4fcaa9347bbbb279866c);
#         });
#     </script>

# %%
# 通过系列配置（.set_series_opts()）控制图表中的文本，线样式，标记等
"""
系列配置项使用示例：
1. 不显示数值
2. 标记每个系列的最大值
"""
bar = (Bar()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1)
       .add_yaxis('门店', data2)
       .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
                        markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max", name="最大值"),]))
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="633bf11f8b784eda9a46a378e20aa009" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_633bf11f8b784eda9a46a378e20aa009 = echarts.init(
#                     document.getElementById('633bf11f8b784eda9a46a378e20aa009'), 'white', {renderer: 'canvas'});
#                 var option_633bf11f8b784eda9a46a378e20aa009 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u95e8\u5e97",
#             "data": [
#                 56,
#                 77,
#                 93,
#                 68,
#                 45,
#                 67
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_633bf11f8b784eda9a46a378e20aa009.setOption(option_633bf11f8b784eda9a46a378e20aa009);
#         });
#     </script>

# %%
# 示例数据
'''
饼图，主标题带链接
'''
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data = [153, 124, 107, 99, 89, 46]

pie = (Pie()
       .add('', [list(z) for z in zip(cate, data)],
            radius=["30%", "75%"],
            rosetype="radius")
       .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例", subtitle="我是副标题", title_link='http://www.baidu.com/'))
       .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {d}%"))
       )

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b393547017b04ec88211d27a24497f7c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b393547017b04ec88211d27a24497f7c = echarts.init(
#                     document.getElementById('b393547017b04ec88211d27a24497f7c'), 'white', {renderer: 'canvas'});
#                 var option_b393547017b04ec88211d27a24497f7c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Apple",
#                     "value": 153
#                 },
#                 {
#                     "name": "Huawei",
#                     "value": 124
#                 },
#                 {
#                     "name": "Xiaomi",
#                     "value": 107
#                 },
#                 {
#                     "name": "Oppo",
#                     "value": 99
#                 },
#                 {
#                     "name": "Vivo",
#                     "value": 89
#                 },
#                 {
#                     "name": "Meizu",
#                     "value": 46
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "link": "http://www.baidu.com/",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b393547017b04ec88211d27a24497f7c.setOption(option_b393547017b04ec88211d27a24497f7c);
#         });
#     </script>
